# %% [markdown]
# # Non Graded Challenge 6

# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()
project_id = "keen-ripsaw-390306"
client = bigquery.Client(project=project_id)

# %%
# put your query here
query = """
      SELECT COUNT(*) AS TOTAL_TABLE
      FROM `bigquery-public-data.austin_bikeshare.__TABLES__`
 """
# Set up the query
query_job1 = client.query(query).to_dataframe()
query_job1
# Out:
#    TOTAL_TABLE
# 0            2

# %%
# put your query here
query = """
        SELECT COUNT(*) AS Total_Columns_String
        FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS`
        WHERE table_name  = 'bikeshare_stations'
        AND data_type = 'STRING'
 """
# Set up the query
query_job2 = client.query(query).to_dataframe()
query_job2
# Out:
#    Total_Columns_String
# 0                     7

# %%
# put your query here
query = """
        SELECT *
        FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
        WHERE bike_id IS NOT NULL
        AND duration_minutes > 1000
 """
# Set up the query
query_job3 = client.query(query).to_dataframe()
query_job3
# Out:
#        trip_id       subscriber_type bike_id bike_type  \
# 0      5385272  24 Hour Walk Up Pass     398   classic
# 1      3394312  24 Hour Walk Up Pass     124   classic
# 2      7164831  24 Hour Walk Up Pass     127   classic
# 3      7486759  24 Hour Walk Up Pass     439   classic
# 4      4991249  24 Hour Walk Up Pass     867   classic
# ...        ...                   ...     ...       ...
# 3449  19288670  24 Hour Walk Up Pass    218G   classic
# 3450  19554748          Single Trip     2205   classic
# 3451  19600027  24 Hour Walk Up Pass     549   classic
# 3452  19146571     HT Ram Membership  15029E  electric
# 3453  19414768          Single Trip     1511   classic
#
#                     start_time  start_station_id  \
# 0    2015-06-20 04:48:27+00:00              2565
# 1    2014-10-04 21:51:04+00:00              2565
# 2    2015-10-10 19:32:38+00:00              2574
# 3    2015-11-01 02:02:28+00:00              2496
# 4    2015-05-24 16:22:57+00:00              2563
# ...

# %%
# put your query here
query = """
      SELECT *
      FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
      WHERE subscriber_type = "Walk Up"
      AND end_station_name = "Stolen"
 """
# Set up the query
query_job4 = client.query(query).to_dataframe()
query_job4
# Out:
#     trip_id subscriber_type bike_id bike_type                start_time  \
# 0  11712091         Walk Up     327   classic 2016-09-02 06:37:15+00:00
# 1  11714202         Walk Up     122   classic 2016-09-02 09:00:56+00:00
# 2  13857913         Walk Up     135   classic 2017-02-26 14:32:45+00:00
# 3  13555129         Walk Up     578   classic 2017-01-27 01:35:26+00:00
# 4  13564817         Walk Up     393   classic 2017-01-28 04:57:28+00:00
# 5  16898448         Walk Up    1857   classic 2018-03-18 22:51:20+00:00
# 6  16863172         Walk Up    1795   classic 2018-03-14 21:23:26+00:00
# 7  17151360         Walk Up    1899   classic 2018-04-21 15:29:10+00:00
#
#    start_station_id                                 start_station_name  \
# 0              2565                               Trinity & 6th Street
# 1              2565                               Trinity & 6th Street
# 2              2566                      Pfluger Bridge @ W 2nd Street
# ...
